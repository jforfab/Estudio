# %%
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline
import numpy as np
import pandas as pd

# %%
# Create some data
rng = np.random.RandomState(0)
x = np.linspace(0, 10, 500)
y = np.cumsum(rng.randn(500, 6), 0)

# %%
# Plot the data with Matplotlib defaults
plt.plot(x, y)
plt.legend('ABCDEF', ncol=2, loc='upper left');

# %%
import seaborn as sns
sns.set()

# %%
# same plotting code as above!
plt.plot(x, y)
plt.legend('ABCDEF', ncol=2, loc='upper left');

# %%
data = np.random.multivariate_normal([0, 0], [[5, 2], [2, 2]],
    size=2000)
data = pd.DataFrame(data, columns=['x', 'y'])
for col in 'xy':
    plt.hist(data[col], normed=True, alpha=0.5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-4dfd16587a9d> in <module>
#       3 data = pd.DataFrame(data, columns=['x', 'y'])
#       4 for col in 'xy':
# ----> 5     plt.hist(data[col], normed=True, alpha=0.5)
#
# c:\users\joshua\miniconda3\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2683         orientation='vertical', rwidth=None, log=False, color=None,
#    2684         label=None, stacked=False, *, data=None, **kwargs):
# -> 2685     return gca().hist(
#    2686         x, bins=bins, range=range, density=density, weights=weights,
#    2687         cumulative=cumulative, bottom=bottom, histtype=histtype,
#
# c:\users\joshua\miniconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
for col in 'xy':
    sns.kdeplot(data[col], shade=True)

# %%
sns.distplot(data['x'])
sns.distplot(data['y']);
# Out:
# c:\users\joshua\miniconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\users\joshua\miniconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.kdeplot(data);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-0357dd8fddc3> in <module>
# ----> 1 sns.kdeplot(data);
#
# c:\users\joshua\miniconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# c:\users\joshua\miniconda3\lib\site-packages\seaborn\distributions.py in kdeplot(x, y, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, weights, hue, palette, hue_order, hue_norm, multiple, common_norm, common_grid, levels, thresh, bw_method, bw_adjust, log_scale, color, fill, data, data2, **kwargs)
#    1694     # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - #
#    1695
# ...

# %%
 with sns.axes_style('white'):
    sns.jointplot("x", "y", data, kind='kde');
# Out:
# c:\users\joshua\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
 
with sns.axes_style('white'):
    sns.jointplot("x", "y", data, kind='hex')
# Out:
# c:\users\joshua\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris, hue='species', size=2.5);
# Out:
# c:\users\joshua\miniconda3\lib\site-packages\seaborn\axisgrid.py:1969: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
type(iris)
# Out:
# pandas.core.frame.DataFrame

# %%
iris.to_csv('isis_dataset.csv')

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.values.nbytes
# Out:
# 13664

# %%
tips['tip_pct'] = 100 * tips['tip'] / tips['total_bill']
grid = sns.FacetGrid(tips, row="sex", col="time", margin_titles=True)
grid.map(plt.hist, "tip_pct", bins=np.linspace(0, 40, 15));

# %%
with sns.axes_style(style='ticks'):
    g = sns.factorplot("day", "total_bill", "sex", data=tips,
    kind="box")
    g.set_axis_labels("Day", "Total Bill");
# Out:
# c:\users\joshua\miniconda3\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# c:\users\joshua\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, hue. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
with sns.axes_style('white'):
    sns.jointplot("total_bill", "tip", data=tips, kind='hex')
# Out:
# c:\users\joshua\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
 sns.jointplot("total_bill", "tip", data=tips, kind='reg');
# Out:
# c:\users\joshua\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
planets = sns.load_dataset('planets')
planets.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
with sns.axes_style('white'):
    g = sns.factorplot("year", data=planets, aspect=2,
    kind="count", color='steelblue')
    g.set_xticklabels(step=5)
# Out:
# c:\users\joshua\miniconda3\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# c:\users\joshua\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
with sns.axes_style('white'):
    g = sns.factorplot("year", data=planets, aspect=4.0, kind='count',
    hue='method', order=range(2001, 2015))
    g.set_ylabels('Number of Planets Discovered')
# Out:
# c:\users\joshua\miniconda3\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# c:\users\joshua\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#!curl -O https://raw.githubusercontent.com/jakevdp/marathon-data/
# master/marathon-data.csv

# %%
descarga='https://raw.githubusercontent.com/jakevdp/marathon-data/master/marathon-data.csv'

# %%
data = pd.read_csv(descarga)
data.to_csv('marathon-data.csv')
data.head()
# Out:
#    age gender     split     final
# 0   33      M  01:05:38  02:08:51
# 1   32      M  01:06:26  02:09:28
# 2   31      M  01:06:49  02:10:42
# 3   38      M  01:06:16  02:13:45
# 4   31      M  01:06:32  02:13:59

# %%
data.values.nbytes
# Out:
# 1192000

# %%
data.values.nbytes/(2**10)**2
# Out:
# 1.13677978515625

# %%
data.dtypes
# Out:
# age        int64
# gender    object
# split     object
# final     object
# dtype: object

# %%
data.columns
# Out:
# Index(['age', 'gender', 'split', 'final'], dtype='object')

# %%
data.describe
# Out:
# <bound method NDFrame.describe of        age gender     split     final
# 0       33      M  01:05:38  02:08:51
# 1       32      M  01:06:26  02:09:28
# 2       31      M  01:06:49  02:10:42
# 3       38      M  01:06:16  02:13:45
# 4       31      M  01:06:32  02:13:59
# ...    ...    ...       ...       ...
# 37245   18      M  04:24:24  09:32:57
# 37246   36      M  04:35:43  09:33:28
# 37247   51      M  04:22:35  09:33:40
# 37248   55      W  04:58:06  10:00:40
# 37249   58      W  04:59:49  10:01:08
#
# [37250 rows x 4 columns]>

# %%
def convert_time(s):
    h, m, s = map(int, s.split(':'))
    return pd.datetools.timedelta(hours=h, minutes=m, seconds=s)
    data = pd.read_csv('marathon-data.csv',
    converters={'split':convert_time,
    'final':convert_time})
data.head()
# Out:
#    age gender     split     final
# 0   33      M  01:05:38  02:08:51
# 1   32      M  01:06:26  02:09:28
# 2   31      M  01:06:49  02:10:42
# 3   38      M  01:06:16  02:13:45
# 4   31      M  01:06:32  02:13:59

# %%
data.dtypes
# Out:
# age        int64
# gender    object
# split     object
# final     object
# dtype: object

# %%
data['split_sec'] = data['split'].astype(int)/1E9
data['final_sec'] = data['final'].astype(int)/1E9
data.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-75c7739566a1> in <module>
# ----> 1 data['split_sec'] = data['split'].astype(int)/1E9
#       2 data['final_sec'] = data['final'].astype(int)/1E9
#       3 data.head()
#
# c:\users\joshua\miniconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# c:\users\joshua\miniconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# ...

# %%
 with sns.axes_style('white'):
    g = sns.jointplot("split_sec", "final_sec", data, kind='hex')
    g.ax_joint.plot(np.linspace(4000, 16000),
    np.linspace(8000, 32000), ':k')
# Out:
# c:\users\joshua\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-e7ae3b653bd0> in <module>
#       1 with sns.axes_style('white'):
# ----> 2    g = sns.jointplot("split_sec", "final_sec", data, kind='hex')
#       3    g.ax_joint.plot(np.linspace(4000, 16000),
#       4    np.linspace(8000, 32000), ':k')
#
# c:\users\joshua\miniconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
# ...

# %%
data = pd.read_csv('marathon-data.csv')
data.head()
# Out:
#    Unnamed: 0  age gender     split     final
# 0           0   33      M  01:05:38  02:08:51
# 1           1   32      M  01:06:26  02:09:28
# 2           2   31      M  01:06:49  02:10:42
# 3           3   38      M  01:06:16  02:13:45
# 4           4   31      M  01:06:32  02:13:59

# %%
type(1E9)
# Out:
# float

# %%
#print(data['split'].astype(int) / 1E9)
print(data['final'])
# Out:
# 0        02:08:51
# 1        02:09:28
# 2        02:10:42
# 3        02:13:45
# 4        02:13:59
#            ...
# 37245    09:32:57
# 37246    09:33:28
# 37247    09:33:40
# 37248    10:00:40
# 37249    10:01:08
# Name: final, Length: 37250, dtype: object

# %%
data['split_sec'] = data['split']
data['final_sec'] = data['final']
data.head()
# Out:
#    Unnamed: 0  age gender     split     final split_sec final_sec
# 0           0   33      M  01:05:38  02:08:51  01:05:38  02:08:51
# 1           1   32      M  01:06:26  02:09:28  01:06:26  02:09:28
# 2           2   31      M  01:06:49  02:10:42  01:06:49  02:10:42
# 3           3   38      M  01:06:16  02:13:45  01:06:16  02:13:45
# 4           4   31      M  01:06:32  02:13:59  01:06:32  02:13:59

# %%
with sns.axes_style('white'):
    g = sns.jointplot("split_sec", "final_sec", data, kind='hex')
    g.ax_joint.plot(np.linspace(4000, 16000),
    np.linspace(8000, 32000), ':k')
# Out:
# c:\users\joshua\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-80ee361eb6dd> in <module>
#       1 with sns.axes_style('white'):
# ----> 2     g = sns.jointplot("split_sec", "final_sec", data, kind='hex')
#       3     g.ax_joint.plot(np.linspace(4000, 16000),
#       4     np.linspace(8000, 32000), ':k')
#
# c:\users\joshua\miniconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ...

# %%
import datetime

# %%
datetime.time.tzinfo(data['split'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-36763a853fc9> in <module>
# ----> 1 datetime.time.tzinfo(data['split'])
#
# TypeError: 'getset_descriptor' object is not callable

# %%
data['split']
# Out:
# 0        01:05:38
# 1        01:06:26
# 2        01:06:49
# 3        01:06:16
# 4        01:06:32
#            ...
# 37245    04:24:24
# 37246    04:35:43
# 37247    04:22:35
# 37248    04:58:06
# 37249    04:59:49
# Name: split, Length: 37250, dtype: object

# %%
from datetime import timedelta
delta = timedelta(
     days=50,
     seconds=27,
     microseconds=10,
     milliseconds=29000,
     minutes=5,
     hours=8,
     weeks=2)
delta
# Out:
# datetime.timedelta(days=64, seconds=29156, microseconds=10)

# %%
from datetime import timedelta
d = timedelta(microseconds=-1)
(d.days, d.seconds, d.microseconds)
# Out:
# (-1, 86399, 999999)

# %%
(data['split'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-6c0c9ec657a8> in <module>
# ----> 1 timeldata(data['split'])
#
# NameError: name 'timeldata' is not defined

# %%
import datetime as dt

# %%
dt.time()
