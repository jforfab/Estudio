# %%
import matplotlib as mlp
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.style.use('classic')

# %%
# ------- file: myplot.py ------
#import matplotlib.pyplot as plt
#import numpy as np
x = np.linspace(0, 10, 100)
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))
plt.show()

# %%
'''
You can then run this script from the command-line prompt, which will result in a window opening with
your figure displayed:
$ python myplot.py
'''
# Out:
# '\nYou can then run this script from the command-line prompt, which will result in a window opening with\nyour figure displayed:\n$ python myplot.py\n'
